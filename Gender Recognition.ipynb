# %% [markdown]
# # ML Project on Gender Recognition by Voice

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Data-Description" data-toc-modified-id="Data-Description-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Description</a></span></li><li><span><a href="#Import-Packages" data-toc-modified-id="Import-Packages-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Import Packages</a></span></li><li><span><a href="#Import-the-Dataset" data-toc-modified-id="Import-the-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Import the Dataset</a></span></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data Exploration</a></span><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Univariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-Target-Variable" data-toc-modified-id="Distribution-of-Target-Variable-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Distribution of Target Variable</a></span></li><li><span><a href="#Distribution-of-Independant-Variables" data-toc-modified-id="Distribution-of-Independant-Variables-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Distribution of Independant Variables</a></span></li><li><span><a href="#Distribution-Independant-Variables" data-toc-modified-id="Distribution-Independant-Variables-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Distribution Independant Variables</a></span></li></ul></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Bivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Corealtion-b/w-Features" data-toc-modified-id="Corealtion-b/w-Features-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Corealtion b/w Features</a></span></li></ul></li></ul></li><li><span><a href="#Scaling-and-Train-Test-split" data-toc-modified-id="Scaling-and-Train-Test-split-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Scaling and Train Test split</a></span><ul class="toc-item"><li><span><a href="#Scaling" data-toc-modified-id="Scaling-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Scaling</a></span></li><li><span><a href="#PCA" data-toc-modified-id="PCA-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Train Test Split</a></span></li></ul></li><li><span><a href="#Modelling-and-prediction" data-toc-modified-id="Modelling-and-prediction-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Modelling and prediction</a></span><ul class="toc-item"><li><span><a href="#CART,-Random-Forest-&amp;-Logistic-Regression" data-toc-modified-id="CART,-Random-Forest-&amp;-Logistic-Regression-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>CART, Random Forest &amp; Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Model-Evaluation¶" data-toc-modified-id="Model-Evaluation¶-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Model Evaluation¶</a></span></li><li><span><a href="#Model-Evalution-Results" data-toc-modified-id="Model-Evalution-Results-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Model Evalution Results</a></span></li><li><span><a href="#ROC_AUC-curve" data-toc-modified-id="ROC_AUC-curve-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>ROC_AUC curve</a></span></li></ul></li><li><span><a href="#Support-Vector-Machines" data-toc-modified-id="Support-Vector-Machines-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Support Vector Machines</a></span><ul class="toc-item"><li><span><a href="#Default-Linear-kernel" data-toc-modified-id="Default-Linear-kernel-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Default Linear kernel</a></span></li><li><span><a href="#Default-RBF-kernel" data-toc-modified-id="Default-RBF-kernel-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Default RBF kernel</a></span></li><li><span><a href="#Default-Polynomial-kernel" data-toc-modified-id="Default-Polynomial-kernel-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Default Polynomial kernel</a></span></li><li><span><a href="#Performing-K-fold-cross-validation-with-different-kernels" data-toc-modified-id="Performing-K-fold-cross-validation-with-different-kernels-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>Performing K-fold cross validation with different kernels</a></span></li><li><span><a href="#Taking-all-the-values-of-C-and-checking-out-the-accuracy-score-with-kernel-as-linear." data-toc-modified-id="Taking-all-the-values-of-C-and-checking-out-the-accuracy-score-with-kernel-as-linear.-7.2.5"><span class="toc-item-num">7.2.5&nbsp;&nbsp;</span>Taking all the values of C and checking out the accuracy score with kernel as linear.</a></span></li><li><span><a href="#Taking-kernel-as-rbf-and-taking-different-values-gamma" data-toc-modified-id="Taking-kernel-as-rbf-and-taking-different-values-gamma-7.2.6"><span class="toc-item-num">7.2.6&nbsp;&nbsp;</span>Taking kernel as rbf and taking different values gamma</a></span></li><li><span><a href="#Taking-polynomial-kernel-with-different-degree" data-toc-modified-id="Taking-polynomial-kernel-with-different-degree-7.2.7"><span class="toc-item-num">7.2.7&nbsp;&nbsp;</span>Taking polynomial kernel with different degree</a></span></li><li><span><a href="#Model-Evalution-Results" data-toc-modified-id="Model-Evalution-Results-7.2.8"><span class="toc-item-num">7.2.8&nbsp;&nbsp;</span>Model Evalution Results</a></span></li></ul></li></ul></li><li><span><a href="#Result" data-toc-modified-id="Result-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Result</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Gender Recognition by Voice and Speech Analysis
#
# This Project aim is to identify a voice as male or female, based upon acoustic properties of the voice and speech.
# The dataset consists of 3,168 recorded voice samples, collected from male and female speakers. The voice samples are pre-processed by acoustic analysis in R using the seewave and tuneR packages, with an analyzed frequency range of 0hz-280hz (human vocal range).

# %% [markdown]
# ##  Data Description

# %% [markdown]
# The Dataset
#
# The following acoustic properties of each voice are measured and included within the CSV:
#
# Attribute Information:
#
# |Variables	    |Description
# |:-----------   |:----------------------------------------------------------------------------------------------- |
# |meanfreq:| mean frequency (in kHz)|
# |sd:| standard deviation of frequency|
# |median:| median frequency (in kHz)|
# |Q25:| first quantile (in kHz)|
# |Q75:| third quantile (in kHz)|
# |IQR:| interquantile range (in kHz)|
# |skew:| skewness (see note in specprop description)|
# |kurt:| kurtosis (see note in specprop description)|
# |sp.ent:| spectral entropy|
# |sfm:| spectral flatness|
# |mode:| mode frequency|
# |centroid:| frequency centroid (see specprop)|
# |peakf:| peak frequency (frequency with highest energy)|
# |meanfun:| average of fundamental frequency measured across acoustic signal|
# |minfun:| minimum fundamental frequency measured across acoustic signal|
# |maxfun:| maximum fundamental frequency measured across acoustic signal|
# |meandom:| average of dominant frequency measured across acoustic signal|
# |mindom:| minimum of dominant frequency measured across acoustic signal|
# |maxdom:| maximum of dominant frequency measured across acoustic signal|
# |dfrange:| range of dominant frequency measured across acoustic signal|
# |modindx:| modulation index. Calculated as the accumulated absolute difference between adjacent measurements of fundamental      frequencies divided by the frequency range|
# |label:| male or female|

# %% [markdown]
# ##  Import Packages

# %%
import numpy as np                     
import pandas as pd

pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', -1)           # To display all the data in each column
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()

import warnings
warnings.filterwarnings('ignore')                   # To suppress all the warnings in the notebook

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)      # To apply seaborn styles to the plots.
# Out:
# <ipython-input-1-cf72e7528d44>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)           # To display all the data in each column

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ##  Import the Dataset

# %%
voice_data = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-3/master/Projects/gender_recognition_by_voice.csv')
voice_data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374  1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325  1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0  274.402906   0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1  634.613855   0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3  4.177296     0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4  4.333713     0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx label
# ...

# %% [markdown]
# ## Data Exploration

# %%
voice_data.shape
# Out:
# (3168, 21)

# %%
voice_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
voice_data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean   0.180907     0.057126     0.185621     0.140456     0.224765
# std    0.029918     0.016652     0.036360     0.048680     0.023639
# min    0.039363     0.018363     0.010975     0.000229     0.042946
# 25%    0.163662     0.041954     0.169593     0.111087     0.208747
# 50%    0.184838     0.059155     0.190032     0.140286     0.225684
# 75%    0.199146     0.067020     0.210618     0.175939     0.243660
# max    0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean   0.084309     3.140168     36.568461    0.895127     0.408216
# std    0.042783     4.240529     134.928661   0.044980     0.177521
# min    0.014558     0.141735     2.068455     0.738651     0.036876
# ...

# %%
voice_data.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %% [markdown]
# ###  Univariate Analysis

# %% [markdown]
# ####  Distribution of Target Variable

# %%
print(voice_data.label.value_counts())
sns.countplot(voice_data.label)
# Out:
# female    1584
# male      1584
# Name: label, dtype: int64
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# - Thus we can see there are equal number of male and female labels

# %% [markdown]
# ####  Distribution of Independant Variables

# %%
X = voice_data.iloc[:,:-1]

# %%
f = pd.melt(voice_data, value_vars=sorted(X))
g = sns.FacetGrid(f,col='variable',col_wrap=4, sharex=False,sharey=False)
g = (g.map(sns.distplot,'value',kde=False,color='g'))

# %% [markdown]
# #### Distribution Independant Variables

# %%
def calc_limits(feature):
    q1,q3=voice_data[feature].quantile([0.25,0.75])
    iqr=q3-q1
    rang=1.5*iqr
    return(q1-rang,q3+rang)

# %%
def plot(feature):
    fig,axes=plt.subplots(1,2)
    sns.boxplot(data=voice_data,x=feature,ax=axes[0])
    sns.distplot(a=voice_data[feature],ax=axes[1],color='#ff4125')
    fig.set_size_inches(15,5)
    
    lower,upper = calc_limits(feature)
    l=[voice_data[feature] for i in voice_data[feature] if i>lower and i<upper] 
    print("Number of data points remaining if outliers removed : ",len(l))

# %%
plot('meanfreq')
# Out:
# Number of data points remaining if outliers removed :  3104

# %%
plot('sd')
# Out:
# Number of data points remaining if outliers removed :  3158

# %%
plot('median')
# Out:
# Number of data points remaining if outliers removed :  3059

# %%
plot('Q25')
# Out:
# Number of data points remaining if outliers removed :  3135

# %%
plot('IQR')
# Out:
# Number of data points remaining if outliers removed :  3158

# %%
plot('skew')
# Out:
# Number of data points remaining if outliers removed :  2938

# %%
plot('kurt')
# Out:
# Number of data points remaining if outliers removed :  2836

# %%
plot('sp.ent')
# Out:
# Number of data points remaining if outliers removed :  3162

# %%
plot('sfm')
# Out:
# Number of data points remaining if outliers removed :  3168

# %%
plot('meanfun')
# Out:
# Number of data points remaining if outliers removed :  3168

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Corealtion b/w Features

# %%
cor_mat= voice_data[:].corr()
mask = np.array(cor_mat)
mask[np.tril_indices_from(mask)] = False
fig=plt.gcf()
sns.set(font_scale=1)
fig.set_size_inches(30,12)
sns.heatmap(data=cor_mat,mask=mask,square=True,annot=True,cbar=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# SOME INFERENCES FROM THE ABOVE HEATMAP--
# 1) Mean frequency is moderately related to label.
#
# 2) IQR and label tend to have a strong positive corelation.
#
# 3) Spectral entropy is also quite highly corelated with the label while sfm is moderately related with label.
#
# 4) skewness and kurtosis aren't much related with label.
#
# 5) meanfun is highly negatively corelated with the label.
#
# 6) Centroid and median have a high positive corelationas expected from their formulae.
#
# 7) Also note that centroid in general has a high degree of corelation with most of the other features.
#
# 8) sd is highly positively related to sfm and so is sp.ent to sd.
#
# 9) kurt and skew are also highly corelated.
#
# 10) meanfreq is highly related to medaina s well as Q25.
#
# 11) IQR is highly corelated to sd.
#
# Note that we can drop some highly correlated features as they add redundancy to the model but let us keep all the features for now. The highly correlated features can be removed by using dimensionality reduction techniques ie Principal Component Analysis(PCA) to reduce our feature space.

# %% [markdown]
# ##  Scaling and Train Test split

# %% [markdown]
# ### Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
X_sc = scaler.transform(X)

# %%
voice_data['label'] = voice_data['label'].map({'male':1, 'female': 0})

# %%
voice_data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374  1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325  1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0  274.402906   0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1  634.613855   0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3  4.177296     0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4  4.333713     0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
y = voice_data.loc[:,voice_data.columns == 'label']

# %%
y
# Out:
#       label
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 3163  0
# 3164  0
# 3165  0
# 3166  0
# 3167  0
#
# [3168 rows x 1 columns]

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(.95).fit(X_sc)

# %%
var=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)
plt.ylabel('% Variance Explained')
plt.xlabel('Number of Features')
plt.title('PCA Analysis')
plt.ylim(30,100.5)
plt.style.context('seaborn-whitegrid')
plt.plot(var)

# %%
print('%d components explain 95%% of the variation in data' % pca.n_components_)
# Out:
# 10 components explain 95% of the variation in data

# %%
pca = PCA(n_components=10, random_state = 0)
pca.fit(X_sc)
X_pca = pca.transform(X_sc)
print(X_pca.shape)
# Out:
# (3168, 10)

# %%
df_X_pca = pd.DataFrame(data = X_pca)
df_X_pca
# Out:
#              0         1         2         3         4         5         6  \
# 0     8.208516  2.164488  1.959784  5.452417  0.930851 -1.202176 -1.239370
# 1     8.671892  3.854627  4.107208  5.079575  0.411480 -0.120161 -0.880189
# 2     9.111169  4.519140  7.528252  3.464543 -0.049165  1.219385 -0.268173
# 3     4.109261 -0.562341 -1.253138 -0.667666  0.003349 -0.965539 -0.348339
# 4     4.057255 -2.272709 -0.576060  0.962292 -0.183624 -0.493363  0.411477
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  3.101277 -2.326595 -0.496518  0.747196  1.882933  2.491250  0.043065
# 3164  5.021255 -1.839262 -0.763118  1.782761  1.773800  1.146319  1.575153
# 3165  3.831378 -1.781434  0.187076 -0.541608  2.214015  1.041211  1.574604
# 3166  3.214419 -1.955633 -0.800871 -0.717154  0.696730  1.339475  0.859644
# 3167  2.361041 -1.339596 -0.913832 -2.666658  2.060982  2.204381  0.550878
#
#              7         8         9
# ...

# %% [markdown]
# ###  Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.20, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (2534, 10)
# (2534, 1)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (634, 10)
# (634, 1)

# %% [markdown]
# ## Modelling and prediction

# %% [markdown]
# ###  CART, Random Forest & Logistic Regression

# %%
model_LR = LogisticRegression()
model_DTC = DecisionTreeClassifier()
model_RFC = RandomForestClassifier()

model_LR.fit(X_train,y_train)
model_DTC.fit(X_train, y_train)
model_RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict_train = list()
y_proba_train = list()

labels = ['LR', 'DTC', 'RF']
models = [model_LR, model_DTC, model_RFC]

for lab, mod in zip(labels, models):
    y_predict_train.append(pd.Series(mod.predict(X_train), name = lab))
    y_proba_train.append(pd.Series(mod.predict_proba(X_train).max(axis=1), name = lab))
    #max(axis = 1) for a 1 dimensional dataframe

y_predict_train = pd.concat(y_predict_train, axis = 1)
y_proba_train = pd.concat(y_proba_train, axis = 1)
print('Train Data Predictions:')
print('Train Data Size:',y_predict_train.shape)
y_predict_train.head()
# Out:
# Train Data Predictions:
# Train Data Size: (2534, 3)
#    LR  DTC  RF
# 0  0   0    0
# 1  1   1    1
# 2  1   1    1
# 3  0   0    0
# 4  1   1    1

# %%
y_predict_test = list()
y_proba_test = list()

labels = ['LR', 'DTC', 'RF']
models = [model_LR, model_DTC, model_RFC]

for lab, mod in zip(labels, models):
    y_predict_test.append(pd.Series(mod.predict(X_test), name = lab))
    y_proba_test.append(pd.Series(mod.predict_proba(X_test).max(axis=1), name = lab))
    #max(axis = 1) for a 1 dimensional dataframe

y_predict_test = pd.concat(y_predict_test, axis = 1)
y_proba_test = pd.concat(y_proba_test, axis = 1)
print('Train Data Predictions:')
print('Train Data Size:',y_predict_test.shape)
y_predict_test.head()
# Out:
# Train Data Predictions:
# Train Data Size: (634, 3)
#    LR  DTC  RF
# 0  0   0    0
# 1  1   1    1
# 2  0   0    0
# 3  0   0    0
# 4  1   0    1

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
# parameters for GridSearchCV
# specify parameters and distributions to sample from
param_dist = {"max_depth": range(2,5),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "n_estimators": [100, 400, 700, 1000, 1500],
              "criterion" : ["gini", "entropy"],
              'max_features': ['sqrt', 'log2', None]
             }
# run randomized search
n_iter_search = 50
random_search = RandomizedSearchCV(model_RFC, param_distributions = param_dist,
                                   n_iter = n_iter_search,
                                   n_jobs = -1)

# %%
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(), n_iter=50, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(2, 5),
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000026C18080B80>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000026C17C57880>,
#                                         'n_estimators': [100, 400, 700, 1000,
#                                                          1500]})

# %%
y_pred_RFCV = random_search.predict(X_test)

# %% [markdown]
# #### Model Evaluation¶

# %% [markdown]
# - Evaluate all the models using Accuracy Score

# %%
Accuracy_LR = accuracy_score(y_test, y_predict_test['LR'])
Accuracy_DTC = accuracy_score(y_test, y_predict_test['DTC'])
Accuracy_RFC = accuracy_score(y_test, y_predict_test['RF'])
Accuracy_RFC_CV = accuracy_score(y_test, y_pred_RFCV)

# %% [markdown]
# - Evaluate all the models using confusion matrix

# %%
conf_mat_LR = confusion_matrix(y_test,y_predict_test['LR'])
conf_mat_DTC = confusion_matrix(y_test,y_predict_test['DTC'])
conf_mat_RFC = confusion_matrix(y_test,y_predict_test['RF'])
conf_mat_RFC_CV = confusion_matrix(y_test,y_pred_RFCV)

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_LR,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of Logistic Regression Model")
plt.show()

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_DTC,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of Decision Tree Classifier Model")
plt.show()

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_RFC,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of Random Forest Classifier Model")
plt.show()

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_RFC_CV,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of Random Forest Classifier with Random Search Model")
plt.show()

# %% [markdown]
# - Precision, Recall & F1 Score

# %%
P_LR = precision_score(y_test, y_predict_test['LR'])
P_DTC = precision_score(y_test, y_predict_test['DTC'])
P_RF = precision_score(y_test, y_predict_test['RF'])
P_RF_CV = precision_score(y_test, y_pred_RFCV)
                      
R_LR = recall_score(y_test,y_predict_test['LR'])
R_DTC = recall_score(y_test, y_predict_test['DTC'])
R_RF = recall_score(y_test, y_predict_test['RF'])
R_RF_CV = recall_score(y_test,y_pred_RFCV)
             
F_LR = f1_score(y_test,y_predict_test['LR'])
F_DTC = f1_score(y_test, y_predict_test['DTC'])
F_RF = f1_score(y_test, y_predict_test['RF']) 
F_RF_CV = f1_score(y_test, y_pred_RFCV)

# %% [markdown]
# #### Model Evalution Results

# %%
labels = labels = ['LR', 'DTC', 'RFC','RFC_CV']
df_score=pd.DataFrame({'Accuracy Score':[Accuracy_LR,Accuracy_DTC,Accuracy_RFC,Accuracy_RFC_CV],
                        'Precision Score':[P_LR,P_DTC,P_RF,P_RF_CV,],'Recall Score':[R_LR,R_DTC,R_RF,R_RF_CV],
                                          'F1_Score':[F_LR,F_DTC,F_RF,F_RF_CV]},index=labels)
df_score
# Out:
#         Accuracy Score  Precision Score  Recall Score  F1_Score
# LR      0.968454        0.956268         0.984985      0.970414
# DTC     0.933754        0.939577         0.933934      0.936747
# RFC     0.963722        0.958580         0.972973      0.965723
# RFC_CV  0.951104        0.944118         0.963964      0.953938

# %% [markdown]
# #### ROC_AUC curve

# %% [markdown]
# - Logistic Regression

# %%
probs = model_LR.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# - Decision Tree Classification

# %%
probs = model_DTC.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# - Random Forest Classification

# %%
probs = model_RFC.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Support Vector Machines

# %%
model_SVC = SVC(random_state = 0) 
model_SVC.fit(X_train, y_train)
y_pred_train_SVC = model_SVC.predict(X_train)
y_pred_test_SVC = model_SVC.predict(X_test)
print('Accuracy score for train data is:', accuracy_score(y_train,y_pred_train_SVC))
test_accuracy_SVC = accuracy_score(y_test,y_pred_test_SVC)
print('Accuracy score for test data is:',test_accuracy_SVC)
# Out:
# Accuracy score for train data is: 0.9826361483820047
# Accuracy score for test data is: 0.9779179810725552

# %% [markdown]
# #### Default Linear kernel

# %%
svc_L=SVC(kernel='linear')
svc_L.fit(X_train,y_train)
y_pred_L=svc_L.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred_L))
# Out:
# Accuracy Score:
# 0.9747634069400631

# %% [markdown]
# ####  Default RBF kernel

# %%
svc_R=SVC(kernel='rbf')
svc_R.fit(X_train,y_train)
y_pred_R=svc_R.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred_R))
# Out:
# Accuracy Score:
# 0.9779179810725552

# %% [markdown]
# #### Default Polynomial kernel

# %%
svc_P=SVC(kernel='poly')
svc_P.fit(X_train,y_train)
y_pred_P=svc_P.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred_P))
# Out:
# Accuracy Score:
# 0.9621451104100947

# %% [markdown]
# Rbf kernel is performing better.

# %% [markdown]
# ####  Performing K-fold cross validation with different kernels

# %%
def generate():
    svc = SVC(kernel='rbf',random_state = 0)
    scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy') 
    return scores.mean()
generate()
# Out:
# 0.9653025793650792

# %%
def generate():
    svc = SVC(kernel='poly',random_state = 0)
    scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy') 
    return scores.mean()
generate()
# Out:
# 0.906795634920635

# %%
def generate():
    svc = SVC(kernel='linear',random_state = 0)
    scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy') 
    return scores.mean()
generate()

Accuracy_SVC_L = generate()
Accuracy_SVC_L
# Out:
# 0.9700644841269842

# %% [markdown]
# - Linear Kernel performing better than others

# %% [markdown]
# #### Taking all the values of C and checking out the accuracy score with kernel as linear.

# %%
C_range1=list(np.arange(1,10))
acc_score1=[]

def generate():
    for c in C_range1:
        svc = SVC(kernel = 'linear', C = c)
        scores1 = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
        acc_score1.append(scores1.mean())
    plt.figure(figsize=(10,4))
    plt.plot(C_range1,acc_score1)
    
    plt.xlabel('Value of C for SVC ')
    
    plt.xticks(np.arange(0.0,10,1))
    
    plt.ylabel('Cross-Validated Accuracy')
    return
generate()

# %% [markdown]
# From the above plot we can see that accuracy has been close to 97.5% for C=6

# %%
C_range2=list(np.arange(0.1,6,0.1))
acc_score2=[]

def generate():
    for c in C_range2:
        svc = SVC(kernel = 'linear', C = c)
        scores2 = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
        acc_score2.append(scores2.mean())
    plt.figure(figsize=(14,6))
    plt.plot(C_range2,acc_score2)
    plt.xlabel('Value of C for SVC ')
    plt.xticks(np.arange(0.0,6,0.1))
    plt.ylabel('Cross-Validated Accuracy')
    return
generate()

# %%
C_range=list(np.arange(0.1,0.5,0.1))
acc_score=[]

def generate():
    for c in C_range:
        svc = SVC(kernel = 'linear', C = c)
        scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
        acc_score.append(scores.mean())
    
    plt.figure(figsize=(10,4))
    plt.plot(C_range,acc_score)
    plt.xlabel('Value of C for SVC ')
    plt.xticks(np.arange(0.0,0.5,0.1))
    plt.ylabel('Cross-Validated Accuracy')
    return
generate()

# %% [markdown]
# - Accuracy score is highest for C=0.3.

# %%
svc_l=SVC(kernel='linear',C=0.3,random_state=0)
svc_l.fit(X_train,y_train)
y_pred_SVC_L=svc_l.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred_SVC_L))
# Out:
# Accuracy Score:
# 0.9747634069400631

# %%
svc = SVC(kernel='linear', C= 0.3)
scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
print('Accuracy Score:')
print(scores.mean())
Accuracy_SVC_L = scores.mean()
# Out:
# Accuracy Score:
# 0.9747767857142857

# %% [markdown]
# - Accuracy is better with C value=0.3 with K-fold Cross Validation

# %%
P_SVC_L = precision_score(y_test, y_pred_SVC_L)
P_SVC_L
# Out:
# 0.967551622418879

# %%
R_SVC_L = recall_score(y_test, y_pred_SVC_L)
R_SVC_L
# Out:
# 0.984984984984985

# %%
F_SVC_L = f1_score(y_test, y_pred_SVC_L)
F_SVC_L
# Out:
# 0.9761904761904762

# %% [markdown]
# #### Taking kernel as rbf and taking different values gamma

# %%
gamma_range1=[0.0001,0.001,0.01,0.1,1,10,100]
acc_score1=[]
for g in gamma_range1:
    svc = SVC(kernel='rbf', gamma=g)
    scores1 = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
    acc_score1.append(scores1.mean())
print(acc_score1)
# Out:
# [0.7663938492063492, 0.8989335317460319, 0.966939484126984, 0.9621527777777776, 0.9085565476190476, 0.5315228174603174, 0.5252232142857143]

# %%
gamma_range=[0.0001,0.001,0.01,0.1,1,10,100]

plt.figure(figsize=(14,6))
plt.plot(gamma_range,acc_score1)
plt.xlabel('Value of gamma for SVC ')
plt.xticks(np.arange(0.0001,100,5))
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# - Let us look into more details for the range 0.0001 to 0.1.

# %%
gamma_range2=[0.0001,0.001,0.01,0.1]
acc_score2=[]
for g in gamma_range2:
    svc = SVC(kernel='rbf', gamma=g)
    scores2 = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
    acc_score2.append(scores2.mean())
print(acc_score2)
# Out:
# [0.7663938492063492, 0.8989335317460319, 0.966939484126984, 0.9621527777777776]

# %%
plt.figure(figsize=(14,6))
plt.plot(gamma_range2,acc_score2)
plt.xlabel('Value of gamma for SVC ')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# - The score increases steadily and raches its peak at 0.01 and then decreases.Thus Gamma should be around 0.01.

# %%
svc_r=SVC(kernel='rbf',gamma=0.01, random_state = 0)
svc_r.fit(X_train,y_train)
y_pred_SVC_R=svc_r.predict(X_test)
print('Accuracy Score:')
Accuracy_SVC_R = metrics.accuracy_score(y_test,y_pred_SVC_R)
print(Accuracy_SVC_R)
# Out:
# Accuracy Score:
# 0.9716088328075709

# %%
svc = SVC(kernel='rbf', gamma=0.01,random_state = 0)
scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
print('Accuracy Score with CV=10:')
print(scores.mean())
# Out:
# Accuracy Score with CV=10:
# 0.966939484126984

# %%
P_SVC_R = precision_score(y_test, y_pred_SVC_R)
P_SVC_R
# Out:
# 0.9701492537313433

# %%
R_SVC_R = recall_score(y_test, y_pred_SVC_R)
R_SVC_R
# Out:
# 0.975975975975976

# %%
F_SVC_R = f1_score(y_test, y_pred_SVC_R)
F_SVC_R
# Out:
# 0.9730538922155688

# %% [markdown]
# ####  Taking polynomial kernel with different degree

# %%
degree1=[2,3,4,5,6]
acc_score1=[]
for d in degree1:
    svc = SVC(kernel='poly', degree=d)
    scores1 = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
    acc_score1.append(scores1.mean())
print(acc_score1)
# Out:
# [0.812127976190476, 0.906795634920635, 0.7473958333333333, 0.7790426587301587, 0.7064484126984126]

# %%
plt.plot(degree1,acc_score1,color='r')
plt.xlabel('degrees for SVC ')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# - Score is high for 3 degree polynomial

# %%
svc_p=SVC(kernel='poly', degree= 3)
svc_p.fit(X_train,y_train)
y_pred_SVC_P = svc_p.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred_SVC_P))
# Out:
# Accuracy Score:
# 0.9621451104100947

# %%
svc = SVC(kernel='poly', degree= 3 )
scores = cross_val_score(svc, X_test, y_test, cv=10, scoring='accuracy')
print('Accuracy Score with CV=10:')
print(scores.mean()) 
Accuracy_SVC_P = scores.mean()
# Out:
# Accuracy Score with CV=10:
# 0.906795634920635

# %%
conf_mat_SVC_L = confusion_matrix(y_test,y_pred_SVC_L)
conf_mat_SVC_R = confusion_matrix(y_test,y_pred_SVC_R)
conf_mat_SVC_P = confusion_matrix(y_test,y_pred_SVC_P)

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_SVC_L,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of SVC with Linear Kernel (C= 0.3) Model")
plt.show()

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_SVC_R,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of SVC with Rbf Kernel(gamma=0.01) Model")
plt.show()

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat_SVC_P,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix of SVC with Poly Kernel (degree = 3) Model")
plt.show()

# %%
P_SVC_P = precision_score(y_test, y_pred_SVC_L)
P_SVC_P
# Out:
# 0.967551622418879

# %%
R_SVC_P = recall_score(y_test, y_pred_SVC_R)
R_SVC_P
# Out:
# 0.975975975975976

# %%
F_SVC_P = f1_score(y_test, y_pred_SVC_P)
F_SVC_P
# Out:
# 0.9644970414201184

# %% [markdown]
# #### Model Evalution Results

# %%
labels = labels = ['SVC_Linear', 'SVC_Rbf', "SVC_Poly"]
df_score_SVC = pd.DataFrame({'Accuracy Score':[Accuracy_SVC_L,Accuracy_SVC_R,Accuracy_SVC_P],
                        'Precision Score':[P_SVC_L,P_SVC_R,P_SVC_P],'Recall Score':[R_SVC_L,R_SVC_R,R_SVC_P],
                                          'F1_Score':[F_SVC_L,F_SVC_R,F_SVC_P]},index=labels)
df_score_SVC
# Out:
#             Accuracy Score  Precision Score  Recall Score  F1_Score
# SVC_Linear  0.974777        0.967552         0.984985      0.976190
# SVC_Rbf     0.971609        0.970149         0.975976      0.973054
# SVC_Poly    0.906796        0.967552         0.975976      0.964497

# %%
# Get support vector indices
support_vector_indices = svc_l.support_

# %%
# Get number of support vectors per class
support_vectors_per_class = svc_l.n_support_
print(support_vectors_per_class)
# Out:
# [111 114]

# %%
# Get support vectors themselves
support_vectors = svc_l.support_vectors_

# Visualize support vectors
plt.scatter(X_test[:,0], X_test[:,1])
plt.scatter(support_vectors[:,0], support_vectors[:,1], color='red')
plt.title('Linearly separable data with support vectors')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# %%
support_vector_indices = svc_r.support_

# %%
support_vectors_per_class = svc_r.n_support_

# %%
# Get support vectors themselves
support_vectors = svc_r.support_vectors_

# Visualize support vectors
plt.scatter(X_test[:,0], X_test[:,1])
plt.scatter(support_vectors[:,0], support_vectors[:,1], color='red')
plt.title('Linearly separable data with support vectors')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# %%
support_vector_indices = svc_p.support_

# %%
support_vectors_per_class = svc_p.n_support_

# %%
# Get support vectors themselves
support_vectors = svc_p.support_vectors_

# Visualize support vectors
plt.scatter(X_test[:,0], X_test[:,1])
plt.scatter(support_vectors[:,0], support_vectors[:,1], color='red')
plt.title('Linearly separable data with support vectors')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# %%
list_accuracy = [Accuracy_LR,Accuracy_DTC,Accuracy_RFC,Accuracy_SVC_L]
list_model = ['LR','DTC','RFC','SVC']
fig, ax = plt.subplots()
fig.set_size_inches(8,5)
sns.barplot(x=list_model, y=list_accuracy, ax=ax,palette ='Dark2')
plt.title('Accuracy Score')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# - The result points out that the algorithm with the highest accuracy is Random Forest Classifier.

# %% [markdown]
# ## Result

# %%
result = pd.concat([df_score,df_score_SVC])
result
# Out:
#             Accuracy Score  Precision Score  Recall Score  F1_Score
# LR          0.968454        0.956268         0.984985      0.970414
# DTC         0.933754        0.939577         0.933934      0.936747
# RFC         0.963722        0.958580         0.972973      0.965723
# RFC_CV      0.951104        0.944118         0.963964      0.953938
# SVC_Linear  0.974777        0.967552         0.984985      0.976190
# SVC_Rbf     0.971609        0.970149         0.975976      0.973054
# SVC_Poly    0.906796        0.967552         0.975976      0.964497

# %% [markdown]
# The result is the calculated accuracies from all models. The accuracies with the different models are compared and the best model is the one which has the highest accuracy with the data. The aim of using multiple models is to identify the best gender recognition model, which can be helpful in developing future applications. The table shows the obtained accuracies of different models.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The main contribution is to find out the best algorithm for the classification Gender from the datasets.
#
# We have compared the performance of these models using Accuracy,Recall, Precision and F1 Score.
#
# The result points out that the algorithm with the highest accuracy is SVM with Linear Kernel. So the best algorithm for Voice Based Gender Classification is SVM with Linear Kernel(C=0.3).
